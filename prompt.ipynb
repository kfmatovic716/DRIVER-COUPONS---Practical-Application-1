# %% [markdown]
# ### Will a Customer Accept the Coupon?
#
# **Overview**
#
# The goal of this project is to use what you know about visualizations and probability distributions to distinguish between customers who accepted a driving coupon versus those that did not.
#
# **Data**
#
#
# This data comes from the UCI Machine Learning repository and was collected via a survey on Amazon Mechanical Turk. The survey describes different driving scenarios including the destination, current time, weather, passenger, etc., and then ask the person whether he will accept the coupon if he is the driver. Answers that the user will drive there ‘right away’ or ‘later before the coupon expires’ are labeled as ‘Y = 1’ and answers ‘no, I do not want the coupon’ are labeled as ‘Y = 0’.  There are five different types of coupons -- less expensive restaurants (under \\$20), coffee houses, carry out & take away, bar, and more expensive restaurants (\\$20 - \\$50).

# %% [markdown]
# **Deliverables**
#
# Your final product should be a brief report that highlights the differences between customers who did and did not accept the coupons.  To explore the data you will utilize your knowledge of plotting, statistical summaries, and visualization using Python. You will publish your findings in a public facing github repository as your first portfolio piece.

# %% [markdown]
# ### Data Description
#
# The attributes of this data set include:
# 1. User attributes
#     -  Gender: male, female
#     -  Age: below 21, 21 to 25, 26 to 30, etc.
#     -  Marital Status: single, married partner, unmarried partner, or widowed
#     -  Number of children: 0, 1, or more than 1
#     -  Education: high school, bachelors degree, associates degree, or graduate degree
#     -  Occupation: architecture & engineering, business & financial, etc.
#     -  Annual income: less than \\$12500, \\$12500 - \\$24999, \\$25000 - \\$37499, etc.
#     -  Number of times that he/she goes to a bar: 0, less than 1, 1 to 3, 4 to 8 or greater than 8
#     -  Number of times that he/she buys takeaway food: 0, less than 1, 1 to 3, 4 to 8 or greater
#     than 8
#     -  Number of times that he/she goes to a coffee house: 0, less than 1, 1 to 3, 4 to 8 or
#     greater than 8
#     -  Number of times that he/she eats at a restaurant with average expense less than \\$20 per
#     person: 0, less than 1, 1 to 3, 4 to 8 or greater than 8
#     -  Number of times that he/she goes to a bar: 0, less than 1, 1 to 3, 4 to 8 or greater than 8
#
# 2. Contextual attributes
#     - Driving destination: home, work, or no urgent destination
#     - Location of user, coupon and destination: we provide a map to show the geographical
#     location of the user, destination, and the venue, and we mark the distance between each
#     two places with time of driving. The user can see whether the venue is in the same
#     direction as the destination.
#     - Weather: sunny, rainy, or snowy
#     - Temperature: 30F, 55F, or 80F
#     - Time: 10AM, 2PM, or 6PM
#     - Passenger: alone, partner, kid(s), or friend(s)
#
# 3. Coupon attributes
#     - time before it expires: 2 hours or one day

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
import plotly.express as px

# %% [markdown]
# ### Problems
#
# Use the prompts below to get started with your data analysis.
#
# 1. Read in the `coupons.csv` file.

# %%
data = pd.read_csv('data/coupons.csv')

# %%
data
# Out:
#            destination  passanger weather  temperature  time  \
# 0      No Urgent Place      Alone   Sunny           55   2PM
# 1      No Urgent Place  Friend(s)   Sunny           80  10AM
# 2      No Urgent Place  Friend(s)   Sunny           80  10AM
# 3      No Urgent Place  Friend(s)   Sunny           80   2PM
# 4      No Urgent Place  Friend(s)   Sunny           80   2PM
# ...                ...        ...     ...          ...   ...
# 12679             Home    Partner   Rainy           55   6PM
# 12680             Work      Alone   Rainy           55   7AM
# 12681             Work      Alone   Snowy           30   7AM
# 12682             Work      Alone   Snowy           30   7AM
# 12683             Work      Alone   Sunny           80   7AM
#
#                       coupon expiration  gender age      maritalStatus  ...  \
# 0            Restaurant(<20)         1d  Female  21  Unmarried partner  ...
# 1               Coffee House         2h  Female  21  Unmarried partner  ...
# 2      Carry out & Take away         2h  Female  21  Unmarried partner  ...
# 3               Coffee House         2h  Female  21  Unmarried partner  ...
# 4               Coffee House         1d  Female  21  Unmarried partner  ...
# ...                      ...        ...     ...  ..                ...  ...
# 12679  Carry out & Take away         1d    Male  26             Single  ...
# 12680  Carry out & Take away         1d    Male  26             Single  ...
# 12681           Coffee House         1d    Male  26             Single  ...
# 12682                    Bar         1d    Male  26             Single  ...
# 12683      Restaurant(20-50)         2h    Male  26             Single  ...
#
#        CoffeeHouse CarryAway RestaurantLessThan20 Restaurant20To50  \
# 0            never       NaN                  4~8              1~3
# 1            never       NaN                  4~8              1~3
# 2            never       NaN                  4~8              1~3
# 3            never       NaN                  4~8              1~3
# 4            never       NaN                  4~8              1~3
# ...            ...       ...                  ...              ...
# 12679        never       1~3                  4~8              1~3
# 12680        never       1~3                  4~8              1~3
# 12681        never       1~3                  4~8              1~3
# 12682        never       1~3                  4~8              1~3
# 12683        never       1~3                  4~8              1~3
#
#       toCoupon_GEQ5min toCoupon_GEQ15min toCoupon_GEQ25min direction_same  \
# 0                    1                 0                 0              0
# 1                    1                 0                 0              0
# 2                    1                 1                 0              0
# 3                    1                 1                 0              0
# 4                    1                 1                 0              0
# ...                ...               ...               ...            ...
# 12679                1                 0                 0              1
# 12680                1                 0                 0              0
# 12681                1                 0                 0              1
# 12682                1                 1                 1              0
# 12683                1                 0                 0              1
#
#       direction_opp  Y
# 0                 1  1
# 1                 1  0
# 2                 1  1
# 3                 1  0
# 4                 1  0
# ...             ... ..
# 12679             0  1
# 12680             1  1
# 12681             0  0
# 12682             1  0
# 12683             0  0
#
# [12684 rows x 26 columns]

# %% [markdown]
# 2. Investigate the dataset for missing or problematic data.

# %%
# Look at number of rows/columns, summary statistics and data types (total counts of numberical/categorical)
print("The data has {} rows and {} columns".format(data.shape[0], data.shape[1]))
display(data.describe())
display(data.dtypes.value_counts())
# Out:
# The data has 12684 rows and 26 columns
#         temperature  has_children  toCoupon_GEQ5min  toCoupon_GEQ15min  \
# count  12684.000000  12684.000000           12684.0       12684.000000
# mean      63.301798      0.414144               1.0           0.561495
# std       19.154486      0.492593               0.0           0.496224
# min       30.000000      0.000000               1.0           0.000000
# 25%       55.000000      0.000000               1.0           0.000000
# 50%       80.000000      0.000000               1.0           1.000000
# 75%       80.000000      1.000000               1.0           1.000000
# max       80.000000      1.000000               1.0           1.000000
#
#        toCoupon_GEQ25min  direction_same  direction_opp             Y
# count       12684.000000    12684.000000   12684.000000  12684.000000
# mean            0.119126        0.214759       0.785241      0.568433
# std             0.323950        0.410671       0.410671      0.495314
# min             0.000000        0.000000       0.000000      0.000000
# 25%             0.000000        0.000000       1.000000      0.000000
# 50%             0.000000        0.000000       1.000000      1.000000
# 75%             0.000000        0.000000       1.000000      1.000000
# max             1.000000        1.000000       1.000000      1.000000
# object    18
# int64      8
# dtype: int64

# %% [markdown]
# #### There are 18 categorical and 8 numerical data

# %%
# Separating numerical and categorical variables
category_vars = data.columns[data.dtypes == 'object']
numeric_vars = data.columns[data.dtypes != 'object']

print(category_vars)
print(numeric_vars)
# Out:
# Index(['destination', 'passanger', 'weather', 'time', 'coupon', 'expiration',
#        'gender', 'age', 'maritalStatus', 'education', 'occupation', 'income',
#        'car', 'Bar', 'CoffeeHouse', 'CarryAway', 'RestaurantLessThan20',
#        'Restaurant20To50'],
#       dtype='object')
# Index(['temperature', 'has_children', 'toCoupon_GEQ5min', 'toCoupon_GEQ15min',
#        'toCoupon_GEQ25min', 'direction_same', 'direction_opp', 'Y'],
#       dtype='object')

# %%
# Get % on missing values in each column of the numerical  
data[numeric_vars].isnull().sum().sort_values(ascending=False)/len(data)
# Out:
# temperature          0.0
# has_children         0.0
# toCoupon_GEQ5min     0.0
# toCoupon_GEQ15min    0.0
# toCoupon_GEQ25min    0.0
# direction_same       0.0
# direction_opp        0.0
# Y                    0.0
# dtype: float64

# %%
# Get counts on missing values in each column of the categorical data
data[category_vars].isnull().sum().sort_values(ascending=False)
# Out:
# car                     12576
# CoffeeHouse               217
# Restaurant20To50          189
# CarryAway                 151
# RestaurantLessThan20      130
# Bar                       107
# passanger                   0
# income                      0
# occupation                  0
# destination                 0
# maritalStatus               0
# age                         0
# gender                      0
# expiration                  0
# coupon                      0
# time                        0
# weather                     0
# education                   0
# dtype: int64

# %%
# Number of original data who accepted/not accepted coupons
data['Y'].value_counts()
# Out:
# 1    7210
# 0    5474
# Name: Y, dtype: int64

# %%
# Get % of missing values in the categorical data
data[category_vars].isnull().sum().sort_values(ascending=False)/len(data)
# Out:
# car                     0.991485
# CoffeeHouse             0.017108
# Restaurant20To50        0.014901
# CarryAway               0.011905
# RestaurantLessThan20    0.010249
# Bar                     0.008436
# passanger               0.000000
# income                  0.000000
# occupation              0.000000
# destination             0.000000
# maritalStatus           0.000000
# age                     0.000000
# gender                  0.000000
# expiration              0.000000
# coupon                  0.000000
# time                    0.000000
# weather                 0.000000
# education               0.000000
# dtype: float64

# %%
# Total number of missing data by column
data[category_vars].isnull().sum().sort_values(ascending=False)
# Out:
# car                     12576
# CoffeeHouse               217
# Restaurant20To50          189
# CarryAway                 151
# RestaurantLessThan20      130
# Bar                       107
# passanger                   0
# income                      0
# occupation                  0
# destination                 0
# maritalStatus               0
# age                         0
# gender                      0
# expiration                  0
# coupon                      0
# time                        0
# weather                     0
# education                   0
# dtype: int64

# %% [markdown]
# ### Check categorical data contents of columns with missing data and decide approach to cleaning

# %%
# Examine the categories in column car that has data
data['car'].value_counts()
# Out:
# Scooter and motorcycle                      22
# Mazda5                                      22
# do not drive                                22
# crossover                                   21
# Car that is too old to install Onstar :D    21
# Name: car, dtype: int64

# %% [markdown]
# #### ***Column car does not affect how we are solving the business problem. Ok to delete the column in cleaning stage and create a new df.

# %%
# Explore missing data on CoffeeHouse: Number of times 
coffeehouse_missing = data[data['CoffeeHouse'].isnull() == True]
coffeehouse_missing
# Out:
#            destination  passanger weather  temperature  time  \
# 495    No Urgent Place      Alone   Sunny           55   2PM
# 496    No Urgent Place  Friend(s)   Sunny           80  10AM
# 497    No Urgent Place  Friend(s)   Sunny           80  10AM
# 498    No Urgent Place  Friend(s)   Sunny           80   2PM
# 499    No Urgent Place  Friend(s)   Sunny           80   2PM
# ...                ...        ...     ...          ...   ...
# 12409             Home      Alone   Sunny           80   6PM
# 12410             Work      Alone   Rainy           55   7AM
# 12411             Work      Alone   Snowy           30   7AM
# 12412             Work      Alone   Snowy           30   7AM
# 12413             Work      Alone   Sunny           80   7AM
#
#                       coupon expiration  gender age      maritalStatus  ...  \
# 495          Restaurant(<20)         1d    Male  26  Unmarried partner  ...
# 496             Coffee House         2h    Male  26  Unmarried partner  ...
# 497    Carry out & Take away         2h    Male  26  Unmarried partner  ...
# 498             Coffee House         2h    Male  26  Unmarried partner  ...
# 499             Coffee House         1d    Male  26  Unmarried partner  ...
# ...                      ...        ...     ...  ..                ...  ...
# 12409      Restaurant(20-50)         1d  Female  36    Married partner  ...
# 12410  Carry out & Take away         1d  Female  36    Married partner  ...
# 12411           Coffee House         1d  Female  36    Married partner  ...
# 12412                    Bar         1d  Female  36    Married partner  ...
# 12413      Restaurant(20-50)         2h  Female  36    Married partner  ...
#
#        CoffeeHouse CarryAway RestaurantLessThan20 Restaurant20To50  \
# 495            NaN     less1                less1            less1
# 496            NaN     less1                less1            less1
# 497            NaN     less1                less1            less1
# 498            NaN     less1                less1            less1
# 499            NaN     less1                less1            less1
# ...            ...       ...                  ...              ...
# 12409          NaN       1~3                  1~3              1~3
# 12410          NaN       1~3                  1~3              1~3
# 12411          NaN       1~3                  1~3              1~3
# 12412          NaN       1~3                  1~3              1~3
# 12413          NaN       1~3                  1~3              1~3
#
#       toCoupon_GEQ5min toCoupon_GEQ15min toCoupon_GEQ25min direction_same  \
# 495                  1                 0                 0              0
# 496                  1                 0                 0              0
# 497                  1                 1                 0              0
# 498                  1                 1                 0              0
# 499                  1                 1                 0              0
# ...                ...               ...               ...            ...
# 12409                1                 0                 0              1
# 12410                1                 0                 0              0
# 12411                1                 0                 0              1
# 12412                1                 1                 1              0
# 12413                1                 0                 0              1
#
#       direction_opp  Y
# 495               1  1
# 496               1  1
# 497               1  0
# 498               1  0
# 499               1  0
# ...             ... ..
# 12409             0  1
# 12410             1  1
# 12411             0  0
# 12412             1  0
# 12413             0  0
#
# [217 rows x 26 columns]

# %% [markdown]
# #### ***Missing data on "CoffeeHouse" column is 1.7% of total data and not significant number. Ok to remove in cleaning stage.

# %%
rest20To50_missing = data[data['Restaurant20To50'].isnull() == True]
rest20To50_missing
# Out:
#            destination  passanger weather  temperature  time  \
# 517    No Urgent Place  Friend(s)   Sunny           80  10AM
# 518    No Urgent Place  Friend(s)   Sunny           80   2PM
# 519    No Urgent Place  Friend(s)   Sunny           80   2PM
# 520    No Urgent Place  Friend(s)   Sunny           80   6PM
# 521    No Urgent Place  Friend(s)   Sunny           55   2PM
# ...                ...        ...     ...          ...   ...
# 12300             Work      Alone   Rainy           55   7AM
# 12301             Work      Alone   Snowy           30   7AM
# 12302             Work      Alone   Snowy           30   7AM
# 12303             Work      Alone   Snowy           30   7AM
# 12304             Work      Alone   Sunny           80   7AM
#
#                       coupon expiration  gender     age maritalStatus  ...  \
# 517                      Bar         1d    Male  50plus      Divorced  ...
# 518             Coffee House         1d    Male  50plus      Divorced  ...
# 519          Restaurant(<20)         1d    Male  50plus      Divorced  ...
# 520             Coffee House         2h    Male  50plus      Divorced  ...
# 521             Coffee House         2h    Male  50plus      Divorced  ...
# ...                      ...        ...     ...     ...           ...  ...
# 12300  Carry out & Take away         1d  Female  50plus       Widowed  ...
# 12301           Coffee House         1d  Female  50plus       Widowed  ...
# 12302        Restaurant(<20)         1d  Female  50plus       Widowed  ...
# 12303                    Bar         1d  Female  50plus       Widowed  ...
# 12304      Restaurant(20-50)         2h  Female  50plus       Widowed  ...
#
#        CoffeeHouse CarryAway RestaurantLessThan20 Restaurant20To50  \
# 517            NaN       NaN                  NaN              NaN
# 518            NaN       NaN                  NaN              NaN
# 519            NaN       NaN                  NaN              NaN
# 520            NaN       NaN                  NaN              NaN
# 521            NaN       NaN                  NaN              NaN
# ...            ...       ...                  ...              ...
# 12300        never       4~8                  1~3              NaN
# 12301        never       4~8                  1~3              NaN
# 12302        never       4~8                  1~3              NaN
# 12303        never       4~8                  1~3              NaN
# 12304        never       4~8                  1~3              NaN
#
#       toCoupon_GEQ5min toCoupon_GEQ15min toCoupon_GEQ25min direction_same  \
# 517                  1                 0                 0              0
# 518                  1                 0                 0              0
# 519                  1                 1                 0              0
# 520                  1                 0                 0              0
# 521                  1                 0                 0              0
# ...                ...               ...               ...            ...
# 12300                1                 0                 0              0
# 12301                1                 0                 0              1
# 12302                1                 1                 0              0
# 12303                1                 1                 1              0
# 12304                1                 0                 0              1
#
#       direction_opp  Y
# 517               1  0
# 518               1  0
# 519               1  1
# 520               1  0
# 521               1  1
# ...             ... ..
# 12300             1  1
# 12301             0  1
# 12302             1  0
# 12303             1  0
# 12304             0  0
#
# [189 rows x 26 columns]

# %% [markdown]
# #### ***Missing data on "Restaurant20To50" column represents 1.5% of the entire dataset and this group has more missing data in other fields like "RestaurantLessThan20", "CoffeeHouse", and "CarryAway". Therefore, ok to drop these records in cleaning stage

# %%
carryaway_missing = data[data['CarryAway'].isnull() == True]
carryaway_missing
# Out:
#           destination  passanger weather  temperature  time  \
# 0     No Urgent Place      Alone   Sunny           55   2PM
# 1     No Urgent Place  Friend(s)   Sunny           80  10AM
# 2     No Urgent Place  Friend(s)   Sunny           80  10AM
# 3     No Urgent Place  Friend(s)   Sunny           80   2PM
# 4     No Urgent Place  Friend(s)   Sunny           80   2PM
# ...               ...        ...     ...          ...   ...
# 8644             Home      Alone   Sunny           80   6PM
# 8645             Work      Alone   Rainy           55   7AM
# 8646             Work      Alone   Snowy           30   7AM
# 8647             Work      Alone   Snowy           30   7AM
# 8648             Work      Alone   Sunny           80   7AM
#
#                      coupon expiration  gender age      maritalStatus  ...  \
# 0           Restaurant(<20)         1d  Female  21  Unmarried partner  ...
# 1              Coffee House         2h  Female  21  Unmarried partner  ...
# 2     Carry out & Take away         2h  Female  21  Unmarried partner  ...
# 3              Coffee House         2h  Female  21  Unmarried partner  ...
# 4              Coffee House         1d  Female  21  Unmarried partner  ...
# ...                     ...        ...     ...  ..                ...  ...
# 8644                    Bar         2h  Female  26    Married partner  ...
# 8645        Restaurant(<20)         2h  Female  26    Married partner  ...
# 8646        Restaurant(<20)         2h  Female  26    Married partner  ...
# 8647      Restaurant(20-50)         1d  Female  26    Married partner  ...
# 8648        Restaurant(<20)         1d  Female  26    Married partner  ...
#
#       CoffeeHouse CarryAway RestaurantLessThan20 Restaurant20To50  \
# 0           never       NaN                  4~8              1~3
# 1           never       NaN                  4~8              1~3
# 2           never       NaN                  4~8              1~3
# 3           never       NaN                  4~8              1~3
# 4           never       NaN                  4~8              1~3
# ...           ...       ...                  ...              ...
# 8644        less1       NaN                less1            less1
# 8645        less1       NaN                less1            less1
# 8646        less1       NaN                less1            less1
# 8647        less1       NaN                less1            less1
# 8648        less1       NaN                less1            less1
#
#      toCoupon_GEQ5min toCoupon_GEQ15min toCoupon_GEQ25min direction_same  \
# 0                   1                 0                 0              0
# 1                   1                 0                 0              0
# 2                   1                 1                 0              0
# 3                   1                 1                 0              0
# 4                   1                 1                 0              0
# ...               ...               ...               ...            ...
# 8644                1                 0                 0              1
# 8645                1                 1                 1              0
# 8646                1                 1                 1              0
# 8647                1                 1                 1              0
# 8648                1                 0                 0              1
#
#      direction_opp  Y
# 0                1  1
# 1                1  0
# 2                1  1
# 3                1  0
# 4                1  0
# ...            ... ..
# 8644             0  1
# 8645             1  0
# 8646             1  0
# 8647             1  0
# 8648             0  0
#
# [151 rows x 26 columns]

# %% [markdown]
# #### ***Missing data on "CarryAway" column represents 1.2% of the entire data. Ok to delete in cleaning stage

# %%
rest_lt20_missing = data[data['RestaurantLessThan20'].isnull() == True]
rest_lt20_missing
# Out:
#           destination  passanger weather  temperature  time  \
# 517   No Urgent Place  Friend(s)   Sunny           80  10AM
# 518   No Urgent Place  Friend(s)   Sunny           80   2PM
# 519   No Urgent Place  Friend(s)   Sunny           80   2PM
# 520   No Urgent Place  Friend(s)   Sunny           80   6PM
# 521   No Urgent Place  Friend(s)   Sunny           55   2PM
# ...               ...        ...     ...          ...   ...
# 8973             Work      Alone   Sunny           30   7AM
# 8974             Work      Alone   Rainy           55   7AM
# 8975             Work      Alone   Sunny           80   7AM
# 8976             Work      Alone   Rainy           55   7AM
# 8977             Work      Alone   Snowy           30   7AM
#
#                      coupon expiration  gender     age      maritalStatus  \
# 517                     Bar         1d    Male  50plus           Divorced
# 518            Coffee House         1d    Male  50plus           Divorced
# 519         Restaurant(<20)         1d    Male  50plus           Divorced
# 520            Coffee House         2h    Male  50plus           Divorced
# 521            Coffee House         2h    Male  50plus           Divorced
# ...                     ...        ...     ...     ...                ...
# 8973                    Bar         1d  Female      21  Unmarried partner
# 8974  Carry out & Take away         2h  Female      21  Unmarried partner
# 8975           Coffee House         1d  Female      21  Unmarried partner
# 8976                    Bar         1d  Female      21  Unmarried partner
# 8977  Carry out & Take away         1d  Female      21  Unmarried partner
#
#       ...  CoffeeHouse CarryAway RestaurantLessThan20 Restaurant20To50  \
# 517   ...          NaN       NaN                  NaN              NaN
# 518   ...          NaN       NaN                  NaN              NaN
# 519   ...          NaN       NaN                  NaN              NaN
# 520   ...          NaN       NaN                  NaN              NaN
# 521   ...          NaN       NaN                  NaN              NaN
# ...   ...          ...       ...                  ...              ...
# 8973  ...          1~3       4~8                  NaN              4~8
# 8974  ...          1~3       4~8                  NaN              4~8
# 8975  ...          1~3       4~8                  NaN              4~8
# 8976  ...          1~3       4~8                  NaN              4~8
# 8977  ...          1~3       4~8                  NaN              4~8
#
#      toCoupon_GEQ5min toCoupon_GEQ15min toCoupon_GEQ25min direction_same  \
# 517                 1                 0                 0              0
# 518                 1                 0                 0              0
# 519                 1                 1                 0              0
# 520                 1                 0                 0              0
# 521                 1                 0                 0              0
# ...               ...               ...               ...            ...
# 8973                1                 1                 0              1
# 8974                1                 1                 0              1
# 8975                1                 0                 0              1
# 8976                1                 1                 1              0
# 8977                1                 1                 0              1
#
#      direction_opp  Y
# 517              1  0
# 518              1  0
# 519              1  1
# 520              1  0
# 521              1  1
# ...            ... ..
# 8973             0  0
# 8974             0  1
# 8975             0  1
# 8976             1  1
# 8977             0  1
#
# [130 rows x 26 columns]

# %% [markdown]
# #### ***Missing data on "RestaurantLessThan20" column represents 1.0% of the entire dataset and this group has more missing data in other fields like "Restaurant20To50", "CoffeeHouse", and "CarryAway". Therefore, ok to drop these records in cleaning stage.

# %%
bar_missing = data[data['Bar'].isnull() == True]
bar_missing
# Out:
#            destination  passanger weather  temperature  time  \
# 517    No Urgent Place  Friend(s)   Sunny           80  10AM
# 518    No Urgent Place  Friend(s)   Sunny           80   2PM
# 519    No Urgent Place  Friend(s)   Sunny           80   2PM
# 520    No Urgent Place  Friend(s)   Sunny           80   6PM
# 521    No Urgent Place  Friend(s)   Sunny           55   2PM
# ...                ...        ...     ...          ...   ...
# 12168             Work      Alone   Rainy           55   7AM
# 12169             Work      Alone   Rainy           55   7AM
# 12170             Work      Alone   Snowy           30   7AM
# 12171             Work      Alone   Snowy           30   7AM
# 12172             Work      Alone   Sunny           80   7AM
#
#                       coupon expiration  gender     age maritalStatus  ...  \
# 517                      Bar         1d    Male  50plus      Divorced  ...
# 518             Coffee House         1d    Male  50plus      Divorced  ...
# 519          Restaurant(<20)         1d    Male  50plus      Divorced  ...
# 520             Coffee House         2h    Male  50plus      Divorced  ...
# 521             Coffee House         2h    Male  50plus      Divorced  ...
# ...                      ...        ...     ...     ...           ...  ...
# 12168        Restaurant(<20)         2h  Female      31        Single  ...
# 12169  Carry out & Take away         1d  Female      31        Single  ...
# 12170           Coffee House         1d  Female      31        Single  ...
# 12171                    Bar         1d  Female      31        Single  ...
# 12172      Restaurant(20-50)         2h  Female      31        Single  ...
#
#        CoffeeHouse CarryAway RestaurantLessThan20 Restaurant20To50  \
# 517            NaN       NaN                  NaN              NaN
# 518            NaN       NaN                  NaN              NaN
# 519            NaN       NaN                  NaN              NaN
# 520            NaN       NaN                  NaN              NaN
# 521            NaN       NaN                  NaN              NaN
# ...            ...       ...                  ...              ...
# 12168        less1       gt8                  1~3            less1
# 12169        less1       gt8                  1~3            less1
# 12170        less1       gt8                  1~3            less1
# 12171        less1       gt8                  1~3            less1
# 12172        less1       gt8                  1~3            less1
#
#       toCoupon_GEQ5min toCoupon_GEQ15min toCoupon_GEQ25min direction_same  \
# 517                  1                 0                 0              0
# 518                  1                 0                 0              0
# 519                  1                 1                 0              0
# 520                  1                 0                 0              0
# 521                  1                 0                 0              0
# ...                ...               ...               ...            ...
# 12168                1                 0                 0              1
# 12169                1                 0                 0              0
# 12170                1                 0                 0              1
# 12171                1                 1                 1              0
# 12172                1                 0                 0              1
#
#       direction_opp  Y
# 517               1  0
# 518               1  0
# 519               1  1
# 520               1  0
# 521               1  1
# ...             ... ..
# 12168             0  0
# 12169             1  0
# 12170             0  1
# 12171             1  0
# 12172             0  0
#
# [107 rows x 26 columns]

# %% [markdown]
# #### ***Missing data on "Bar" column represents 0.8% of the entire dataset, which is very insignificant.Additionaly, this group has more missing data in other fields like "RestaurantLessThan20", "CoffeeHouse", and "CarryAway". Therefore, ok to drop these records in cleaning stage

# %% [markdown]
# 3. Decide what to do about your missing data -- drop, replace, other...

# %%
# Create a new df without the "car" column
new_df = data.drop("car", axis=1)
new_df
# Out:
#            destination  passanger weather  temperature  time  \
# 0      No Urgent Place      Alone   Sunny           55   2PM
# 1      No Urgent Place  Friend(s)   Sunny           80  10AM
# 2      No Urgent Place  Friend(s)   Sunny           80  10AM
# 3      No Urgent Place  Friend(s)   Sunny           80   2PM
# 4      No Urgent Place  Friend(s)   Sunny           80   2PM
# ...                ...        ...     ...          ...   ...
# 12679             Home    Partner   Rainy           55   6PM
# 12680             Work      Alone   Rainy           55   7AM
# 12681             Work      Alone   Snowy           30   7AM
# 12682             Work      Alone   Snowy           30   7AM
# 12683             Work      Alone   Sunny           80   7AM
#
#                       coupon expiration  gender age      maritalStatus  ...  \
# 0            Restaurant(<20)         1d  Female  21  Unmarried partner  ...
# 1               Coffee House         2h  Female  21  Unmarried partner  ...
# 2      Carry out & Take away         2h  Female  21  Unmarried partner  ...
# 3               Coffee House         2h  Female  21  Unmarried partner  ...
# 4               Coffee House         1d  Female  21  Unmarried partner  ...
# ...                      ...        ...     ...  ..                ...  ...
# 12679  Carry out & Take away         1d    Male  26             Single  ...
# 12680  Carry out & Take away         1d    Male  26             Single  ...
# 12681           Coffee House         1d    Male  26             Single  ...
# 12682                    Bar         1d    Male  26             Single  ...
# 12683      Restaurant(20-50)         2h    Male  26             Single  ...
#
#        CoffeeHouse CarryAway RestaurantLessThan20 Restaurant20To50  \
# 0            never       NaN                  4~8              1~3
# 1            never       NaN                  4~8              1~3
# 2            never       NaN                  4~8              1~3
# 3            never       NaN                  4~8              1~3
# 4            never       NaN                  4~8              1~3
# ...            ...       ...                  ...              ...
# 12679        never       1~3                  4~8              1~3
# 12680        never       1~3                  4~8              1~3
# 12681        never       1~3                  4~8              1~3
# 12682        never       1~3                  4~8              1~3
# 12683        never       1~3                  4~8              1~3
#
#       toCoupon_GEQ5min toCoupon_GEQ15min toCoupon_GEQ25min direction_same  \
# 0                    1                 0                 0              0
# 1                    1                 0                 0              0
# 2                    1                 1                 0              0
# 3                    1                 1                 0              0
# 4                    1                 1                 0              0
# ...                ...               ...               ...            ...
# 12679                1                 0                 0              1
# 12680                1                 0                 0              0
# 12681                1                 0                 0              1
# 12682                1                 1                 1              0
# 12683                1                 0                 0              1
#
#       direction_opp  Y
# 0                 1  1
# 1                 1  0
# 2                 1  1
# 3                 1  0
# 4                 1  0
# ...             ... ..
# 12679             0  1
# 12680             1  1
# 12681             0  0
# 12682             1  0
# 12683             0  0
#
# [12684 rows x 25 columns]

# %%
# Confirm car column was deleted; Result should be 25 columns
print(new_df.shape)
new_df.columns
# Out:
# (12684, 25)
# Index(['destination', 'passanger', 'weather', 'temperature', 'time', 'coupon',
#        'expiration', 'gender', 'age', 'maritalStatus', 'has_children',
#        'education', 'occupation', 'income', 'Bar', 'CoffeeHouse', 'CarryAway',
#        'RestaurantLessThan20', 'Restaurant20To50', 'toCoupon_GEQ5min',
#        'toCoupon_GEQ15min', 'toCoupon_GEQ25min', 'direction_same',
#        'direction_opp', 'Y'],
#       dtype='object')

# %%
# Execute the dropping of all missing data as noted above with ***
final_df = new_df.dropna()
final_df
# Out:
#            destination  passanger weather  temperature  time  \
# 22     No Urgent Place      Alone   Sunny           55   2PM
# 23     No Urgent Place  Friend(s)   Sunny           80  10AM
# 24     No Urgent Place  Friend(s)   Sunny           80  10AM
# 25     No Urgent Place  Friend(s)   Sunny           80  10AM
# 26     No Urgent Place  Friend(s)   Sunny           80   2PM
# ...                ...        ...     ...          ...   ...
# 12679             Home    Partner   Rainy           55   6PM
# 12680             Work      Alone   Rainy           55   7AM
# 12681             Work      Alone   Snowy           30   7AM
# 12682             Work      Alone   Snowy           30   7AM
# 12683             Work      Alone   Sunny           80   7AM
#
#                       coupon expiration gender age maritalStatus  ...  \
# 22           Restaurant(<20)         1d   Male  21        Single  ...
# 23              Coffee House         2h   Male  21        Single  ...
# 24                       Bar         1d   Male  21        Single  ...
# 25     Carry out & Take away         2h   Male  21        Single  ...
# 26              Coffee House         1d   Male  21        Single  ...
# ...                      ...        ...    ...  ..           ...  ...
# 12679  Carry out & Take away         1d   Male  26        Single  ...
# 12680  Carry out & Take away         1d   Male  26        Single  ...
# 12681           Coffee House         1d   Male  26        Single  ...
# 12682                    Bar         1d   Male  26        Single  ...
# 12683      Restaurant(20-50)         2h   Male  26        Single  ...
#
#        CoffeeHouse CarryAway RestaurantLessThan20 Restaurant20To50  \
# 22           less1       4~8                  4~8            less1
# 23           less1       4~8                  4~8            less1
# 24           less1       4~8                  4~8            less1
# 25           less1       4~8                  4~8            less1
# 26           less1       4~8                  4~8            less1
# ...            ...       ...                  ...              ...
# 12679        never       1~3                  4~8              1~3
# 12680        never       1~3                  4~8              1~3
# 12681        never       1~3                  4~8              1~3
# 12682        never       1~3                  4~8              1~3
# 12683        never       1~3                  4~8              1~3
#
#       toCoupon_GEQ5min toCoupon_GEQ15min toCoupon_GEQ25min direction_same  \
# 22                   1                 0                 0              0
# 23                   1                 0                 0              0
# 24                   1                 0                 0              0
# 25                   1                 1                 0              0
# 26                   1                 0                 0              0
# ...                ...               ...               ...            ...
# 12679                1                 0                 0              1
# 12680                1                 0                 0              0
# 12681                1                 0                 0              1
# 12682                1                 1                 1              0
# 12683                1                 0                 0              1
#
#       direction_opp  Y
# 22                1  1
# 23                1  0
# 24                1  1
# 25                1  0
# 26                1  0
# ...             ... ..
# 12679             0  1
# 12680             1  1
# 12681             0  0
# 12682             1  0
# 12683             0  0
#
# [12079 rows x 25 columns]

# %%
print("The final data has {} rows and {} columns".format(final_df.shape[0], final_df.shape[1]))
display(final_df.dtypes.value_counts())
# Out:
# The final data has 12079 rows and 25 columns
# object    17
# int64      8
# dtype: int64

# %% [markdown]
# #### Final dataset total count was better than what was expected. Originally, we could have expected the final count to be approximately 11,890 [12,684-794(total count of missing)] assuming there are no overlaps with the missing data. However, due to the overlaps in missing data across columns, there were fewer records dropped and the resulting count was much higher than expected, which is better because we have preserved more data.

# %%
# Confirmation no more missing data in the final data
final_df.isnull().sum()
# Out:
# destination             0
# passanger               0
# weather                 0
# temperature             0
# time                    0
# coupon                  0
# expiration              0
# gender                  0
# age                     0
# maritalStatus           0
# has_children            0
# education               0
# occupation              0
# income                  0
# Bar                     0
# CoffeeHouse             0
# CarryAway               0
# RestaurantLessThan20    0
# Restaurant20To50        0
# toCoupon_GEQ5min        0
# toCoupon_GEQ15min       0
# toCoupon_GEQ25min       0
# direction_same          0
# direction_opp           0
# Y                       0
# dtype: int64

# %% [markdown]
# 4. What proportion of the total observations chose to accept the coupon?

# %%
# Get proportions of coupon acceptance (Y=1: accepted, Y=0: not accepted)
coupon_acceptance = final_df['Y'].value_counts()
coupon_acceptance
# Out:
# 1    6877
# 0    5202
# Name: Y, dtype: int64

# %%
# Proportion of user accepting the coupon
accepted = coupon_acceptance[1]/len(final_df)
accepted
# Out:
# 0.5693352098683666

# %% [markdown]
# 5. Use a bar plot to visualize the `coupon` column.

# %%
final_df['coupon'].value_counts()
# Out:
# Coffee House             3816
# Restaurant(<20)          2653
# Carry out & Take away    2280
# Bar                      1913
# Restaurant(20-50)        1417
# Name: coupon, dtype: int64

# %%
# shows the total number of coupons by type of coupon
px.bar(final_df, x="coupon")

# %% [markdown]
# 6. Use a histogram to visualize the temperature column.

# %%
final_df["temperature"].value_counts()
# Out:
# 80    6222
# 55    3662
# 30    2195
# Name: temperature, dtype: int64

# %%
px.histogram(final_df["temperature"])

# %% [markdown]
# **Investigating the Bar Coupons**
#
# Now, we will lead you through an exploration of just the bar related coupons.
#
# 1. Create a new `DataFrame` that contains just the bar coupons.

# %%
# Select data with customers getting Bar coupons
Bar = final_df.query('coupon=="Bar"')
Bar
# Out:
#            destination  passanger weather  temperature  time coupon  \
# 24     No Urgent Place  Friend(s)   Sunny           80  10AM    Bar
# 35                Home      Alone   Sunny           55   6PM    Bar
# 39                Work      Alone   Sunny           55   7AM    Bar
# 46     No Urgent Place  Friend(s)   Sunny           80  10AM    Bar
# 57                Home      Alone   Sunny           55   6PM    Bar
# ...                ...        ...     ...          ...   ...    ...
# 12663  No Urgent Place  Friend(s)   Sunny           80  10PM    Bar
# 12664  No Urgent Place  Friend(s)   Sunny           55  10PM    Bar
# 12667  No Urgent Place      Alone   Rainy           55  10AM    Bar
# 12670  No Urgent Place    Partner   Rainy           55   6PM    Bar
# 12682             Work      Alone   Snowy           30   7AM    Bar
#
#       expiration gender age maritalStatus  ...  CoffeeHouse CarryAway  \
# 24            1d   Male  21        Single  ...        less1       4~8
# 35            1d   Male  21        Single  ...        less1       4~8
# 39            1d   Male  21        Single  ...        less1       4~8
# 46            1d   Male  46        Single  ...          4~8       1~3
# 57            1d   Male  46        Single  ...          4~8       1~3
# ...          ...    ...  ..           ...  ...          ...       ...
# 12663         1d   Male  26        Single  ...        never       1~3
# 12664         2h   Male  26        Single  ...        never       1~3
# 12667         1d   Male  26        Single  ...        never       1~3
# 12670         2h   Male  26        Single  ...        never       1~3
# 12682         1d   Male  26        Single  ...        never       1~3
#
#       RestaurantLessThan20 Restaurant20To50 toCoupon_GEQ5min  \
# 24                     4~8            less1                1
# 35                     4~8            less1                1
# 39                     4~8            less1                1
# 46                     1~3            never                1
# 57                     1~3            never                1
# ...                    ...              ...              ...
# 12663                  4~8              1~3                1
# 12664                  4~8              1~3                1
# 12667                  4~8              1~3                1
# 12670                  4~8              1~3                1
# 12682                  4~8              1~3                1
#
#       toCoupon_GEQ15min toCoupon_GEQ25min direction_same direction_opp  Y
# 24                    0                 0              0             1  1
# 35                    0                 0              1             0  1
# 39                    1                 1              0             1  1
# 46                    0                 0              0             1  0
# 57                    0                 0              1             0  0
# ...                 ...               ...            ...           ... ..
# 12663                 1                 0              0             1  0
# 12664                 1                 0              0             1  0
# 12667                 1                 0              0             1  0
# 12670                 1                 0              0             1  0
# 12682                 1                 1              0             1  0
#
# [1913 rows x 25 columns]

# %%
# Total Bar coupons given out to a customer
Bar.shape[0]
# Out:
# 1913

# %%
# Accepted Bar coupons
Bar_accepted = final_df[(final_df['coupon'] == 'Bar') & (final_df['Y'] == 1)]
Bar_accepted
# Out:
#            destination  passanger weather  temperature  time coupon  \
# 24     No Urgent Place  Friend(s)   Sunny           80  10AM    Bar
# 35                Home      Alone   Sunny           55   6PM    Bar
# 39                Work      Alone   Sunny           55   7AM    Bar
# 75     No Urgent Place     Kid(s)   Sunny           80  10AM    Bar
# 79                Home      Alone   Sunny           55   6PM    Bar
# ...                ...        ...     ...          ...   ...    ...
# 12570  No Urgent Place  Friend(s)   Sunny           55  10PM    Bar
# 12573  No Urgent Place      Alone   Rainy           55  10AM    Bar
# 12591  No Urgent Place  Friend(s)   Sunny           80  10PM    Bar
# 12644  No Urgent Place  Friend(s)   Sunny           55  10PM    Bar
# 12652             Home    Partner   Sunny           30  10PM    Bar
#
#       expiration  gender     age    maritalStatus  ...  CoffeeHouse CarryAway  \
# 24            1d    Male      21           Single  ...        less1       4~8
# 35            1d    Male      21           Single  ...        less1       4~8
# 39            1d    Male      21           Single  ...        less1       4~8
# 75            1d    Male      46  Married partner  ...          1~3       1~3
# 79            1d    Male      46  Married partner  ...          1~3       1~3
# ...          ...     ...     ...              ...  ...          ...       ...
# 12570         2h    Male      21           Single  ...        never       1~3
# 12573         1d    Male      21           Single  ...        never       1~3
# 12591         1d  Female  50plus         Divorced  ...        less1       1~3
# 12644         2h    Male      31  Married partner  ...        never       4~8
# 12652         2h    Male      31  Married partner  ...        never       4~8
#
#       RestaurantLessThan20 Restaurant20To50 toCoupon_GEQ5min  \
# 24                     4~8            less1                1
# 35                     4~8            less1                1
# 39                     4~8            less1                1
# 75                     1~3            less1                1
# 79                     1~3            less1                1
# ...                    ...              ...              ...
# 12570                  1~3            less1                1
# 12573                  1~3            less1                1
# 12591                  1~3            less1                1
# 12644                  gt8            less1                1
# 12652                  gt8            less1                1
#
#       toCoupon_GEQ15min toCoupon_GEQ25min direction_same direction_opp  Y
# 24                    0                 0              0             1  1
# 35                    0                 0              1             0  1
# 39                    1                 1              0             1  1
# 75                    1                 0              0             1  1
# 79                    0                 0              1             0  1
# ...                 ...               ...            ...           ... ..
# 12570                 1                 0              0             1  1
# 12573                 1                 0              0             1  1
# 12591                 1                 0              0             1  1
# 12644                 1                 0              0             1  1
# 12652                 1                 1              0             1  1
#
# [788 rows x 25 columns]

# %%
Bar_accepted.shape[0]
# Out:
# 788

# %% [markdown]
# 2. What proportion of bar coupons were accepted?

# %%
# Percent of Bar coupons accepted
pct_bar_coupons_accepted = Bar_accepted.shape[0]/Bar.shape[0]
pct_bar_coupons_accepted
# Out:
# 0.41191845269210664

# %% [markdown]
# #### 41% of Bar coupons were accepted

# %% [markdown]
# 3. Compare the acceptance rate between those who went to a bar 3 or fewer times a month to those who went more.

# %%
# Among the customers who have accepted the bar coupons, these categories represent the frequency of a customer goes to a Bar 
# i.e. there are 33 customers who accepted the Bar coupon who goes to the bar more than 8 times in a month
Bar_accepted['Bar'].value_counts()
# Out:
# less1    247
# 1~3      245
# never    149
# 4~8      114
# gt8       33
# Name: Bar, dtype: int64

# %%
# Total number of customers who visited the bar <= 3 times
fewer_bar_visits = Bar_accepted["Bar"].value_counts()["never"] + Bar_accepted["Bar"].value_counts()["less1"] + Bar_accepted["Bar"].value_counts()["1~3"]
fewer_bar_visits
# Out:
# 641

# %%
# acceptance rate of those who went to a bar 3 or fewer times a month
fewerBar_AR = fewer_bar_visits / Bar_accepted.shape[0]
fewerBar_AR
# Out:
# 0.8134517766497462

# %%
# Total number of customers who visited the bar more than 3 times
morethan3_bar_visits = Bar_accepted["Bar"].value_counts()["4~8"] + Bar_accepted["Bar"].value_counts()["gt8"]
morethan3_bar_visits
# Out:
# 147

# %%
# acceptance rate for customers who have visited the bar more than 3 times
pct_gt8_barvisits = 1 - fewerBar_AR
pct_gt8_barvisits
# Out:
# 0.18654822335025378

# %% [markdown]
# #### Acceptance rate of those who went to bar fewer than 3 times a month is about 81% compared to 19% who went more than 3 times per month

# %% [markdown]
# 4. Compare the acceptance rate between drivers who go to a bar more than once a month and are over the age of 25 to the all others.  Is there a difference?

# %%
Indexed_Bar_accepted = Bar_accepted.set_index('Bar')
Indexed_Bar_accepted
# Out:
#            destination  passanger weather  temperature  time coupon  \
# Bar
# never  No Urgent Place  Friend(s)   Sunny           80  10AM    Bar
# never             Home      Alone   Sunny           55   6PM    Bar
# never             Work      Alone   Sunny           55   7AM    Bar
# less1  No Urgent Place     Kid(s)   Sunny           80  10AM    Bar
# less1             Home      Alone   Sunny           55   6PM    Bar
# ...                ...        ...     ...          ...   ...    ...
# never  No Urgent Place  Friend(s)   Sunny           55  10PM    Bar
# never  No Urgent Place      Alone   Rainy           55  10AM    Bar
# never  No Urgent Place  Friend(s)   Sunny           80  10PM    Bar
# less1  No Urgent Place  Friend(s)   Sunny           55  10PM    Bar
# less1             Home    Partner   Sunny           30  10PM    Bar
#
#       expiration  gender     age    maritalStatus  ...  CoffeeHouse CarryAway  \
# Bar                                                ...
# never         1d    Male      21           Single  ...        less1       4~8
# never         1d    Male      21           Single  ...        less1       4~8
# never         1d    Male      21           Single  ...        less1       4~8
# less1         1d    Male      46  Married partner  ...          1~3       1~3
# less1         1d    Male      46  Married partner  ...          1~3       1~3
# ...          ...     ...     ...              ...  ...          ...       ...
# never         2h    Male      21           Single  ...        never       1~3
# never         1d    Male      21           Single  ...        never       1~3
# never         1d  Female  50plus         Divorced  ...        less1       1~3
# less1         2h    Male      31  Married partner  ...        never       4~8
# less1         2h    Male      31  Married partner  ...        never       4~8
#
#       RestaurantLessThan20 Restaurant20To50 toCoupon_GEQ5min  \
# Bar
# never                  4~8            less1                1
# never                  4~8            less1                1
# never                  4~8            less1                1
# less1                  1~3            less1                1
# less1                  1~3            less1                1
# ...                    ...              ...              ...
# never                  1~3            less1                1
# never                  1~3            less1                1
# never                  1~3            less1                1
# less1                  gt8            less1                1
# less1                  gt8            less1                1
#
#       toCoupon_GEQ15min toCoupon_GEQ25min direction_same  direction_opp  Y
# Bar
# never                 0                 0              0              1  1
# never                 0                 0              1              0  1
# never                 1                 1              0              1  1
# less1                 1                 0              0              1  1
# less1                 0                 0              1              0  1
# ...                 ...               ...            ...            ... ..
# never                 1                 0              0              1  1
# never                 1                 0              0              1  1
# never                 1                 0              0              1  1
# less1                 1                 0              0              1  1
# less1                 1                 1              0              1  1
#
# [788 rows x 24 columns]

# %%
Indexed_Bar_accepted.shape[0]
# Out:
# 788

# %%
# Total number of drivers who go to a bar more than once a month and all ages
barAccepted_gt1_allages = Indexed_Bar_accepted.loc[['1~3', '4~8', 'gt8'], ['age']].value_counts()
barAccepted_gt1_allages
# Out:
# age
# 26         122
# 21         110
# 31          61
# 50plus      42
# 41          21
# 36          20
# 46          12
# below21      4
# dtype: int64

# %%
# Total number of drivers who go to a bar more than once a month and ages over 25
barAccepted_gt1_over25 = barAccepted_gt1_allages[0:7].sum()
barAccepted_gt1_over25
# Out:
# 388

# %%
# Percentage of drivers who go to a bar more than once a month and ages over 25
pct_gt1_over25 = barAccepted_gt1_over25 / Indexed_Bar_accepted.shape[0]
pct_gt1_over25
# Out:
# 0.49238578680203043

# %%
allothers_pct = 1-pct_gt1_over25
allothers_pct
# Out:
# 0.5076142131979695

# %% [markdown]
# #### Acceptance rate of drivers who go to a bar more than once a month and ages over 25 is approximately 49% and all others are 51% as well.

# %% [markdown]
# 5. Construct a null and alternative hypothesis for the difference between groups of drivers who go to a bar more than once a month and are over the age of 25 to all other drivers.

# %% [markdown]
# 6. Using alpha at 0.05 test your hypothesis and state your conclusion.

# %% [markdown]
# 7. Use the same process to compare the acceptance rate between drivers who go to bars more than once a month and had passengers that were not a kid and had occupations other than farming, fishing, or forestry.

# %%
# Drivers who go to bars gt once a month and had no kid passenger
groups = ['1~3', '4~8', 'gt8']
passengers = ['Alone', 'Friend(s)', 'Partner']

Bar_gt1mo_noKids = Bar_accepted.query("Bar in @groups and passanger in @passengers")
Bar_gt1mo_noKids
# Out:
#            destination  passanger weather  temperature  time coupon  \
# 90     No Urgent Place  Friend(s)   Sunny           80  10AM    Bar
# 101               Home      Alone   Sunny           55   6PM    Bar
# 112    No Urgent Place  Friend(s)   Sunny           80  10AM    Bar
# 123               Home      Alone   Sunny           55   6PM    Bar
# 127               Work      Alone   Sunny           55   7AM    Bar
# ...                ...        ...     ...          ...   ...    ...
# 12482  No Urgent Place  Friend(s)   Sunny           55  10PM    Bar
# 12485  No Urgent Place      Alone   Rainy           55  10AM    Bar
# 12488  No Urgent Place    Partner   Rainy           55   6PM    Bar
# 12525  No Urgent Place  Friend(s)   Sunny           80  10PM    Bar
# 12526  No Urgent Place  Friend(s)   Sunny           55  10PM    Bar
#
#       expiration  gender age      maritalStatus  ...  CoffeeHouse CarryAway  \
# 90            1d    Male  21             Single  ...        less1       1~3
# 101           1d    Male  21             Single  ...        less1       1~3
# 112           1d    Male  26  Unmarried partner  ...          gt8       4~8
# 123           1d    Male  26  Unmarried partner  ...          gt8       4~8
# 127           1d    Male  26  Unmarried partner  ...          gt8       4~8
# ...          ...     ...  ..                ...  ...          ...       ...
# 12482         2h  Female  26  Unmarried partner  ...        never       4~8
# 12485         1d  Female  26  Unmarried partner  ...        never       4~8
# 12488         2h  Female  26  Unmarried partner  ...        never       4~8
# 12525         1d    Male  21  Unmarried partner  ...        never       gt8
# 12526         2h    Male  21  Unmarried partner  ...        never       gt8
#
#       RestaurantLessThan20 Restaurant20To50 toCoupon_GEQ5min  \
# 90                   less1              1~3                1
# 101                  less1              1~3                1
# 112                    1~3            less1                1
# 123                    1~3            less1                1
# 127                    1~3            less1                1
# ...                    ...              ...              ...
# 12482                  4~8            less1                1
# 12485                  4~8            less1                1
# 12488                  4~8            less1                1
# 12525                  4~8              1~3                1
# 12526                  4~8              1~3                1
#
#       toCoupon_GEQ15min toCoupon_GEQ25min direction_same direction_opp  Y
# 90                    0                 0              0             1  1
# 101                   0                 0              1             0  1
# 112                   0                 0              0             1  1
# 123                   0                 0              1             0  1
# 127                   1                 1              0             1  1
# ...                 ...               ...            ...           ... ..
# 12482                 1                 0              0             1  1
# 12485                 1                 0              0             1  1
# 12488                 1                 0              0             1  1
# 12525                 1                 0              0             1  1
# 12526                 1                 0              0             1  1
#
# [376 rows x 25 columns]

# %%
Bar_gt1mo_noKids.shape[0]
# Out:
# 376

# %%
# Check if there are occupations in farming, fishing, or forestry. There is none. Therefore, Bar_gt1mo_noKids is the df for #7
Bar_gt1mo_noKids['occupation'].value_counts()
# Out:
# Unemployed                                   57
# Student                                      43
# Sales & Related                              42
# Management                                   35
# Office & Administrative Support              30
# Computer & Mathematical                      27
# Arts Design Entertainment Sports & Media     17
# Business & Financial                         15
# Protective Service                           12
# Food Preparation & Serving Related           11
# Healthcare Practitioners & Technical         11
# Legal                                        10
# Healthcare Support                           10
# Education&Training&Library                    8
# Production Occupations                        8
# Transportation & Material Moving              7
# Architecture & Engineering                    6
# Construction & Extraction                     6
# Personal Care & Service                       6
# Installation Maintenance & Repair             5
# Community & Social Services                   5
# Retired                                       2
# Life Physical Social Science                  2
# Building & Grounds Cleaning & Maintenance     1
# Name: occupation, dtype: int64

# %%
# Percent of Drivers who go to bars gt once a month and had no kid passenger and not working in farm, forest or fishing
pct_Bar_gt1mo_noKids = Bar_gt1mo_noKids.shape[0] / Bar_accepted.shape[0]
pct_Bar_gt1mo_noKids
# Out:
# 0.47715736040609136

# %% [markdown]
# #### Acceptance rate of drivers who go to bars more than once a month, had no kid passenger and not working in farm, fishing or forest is  48%

# %% [markdown]
# 8. Compare the acceptance rates between those passengers who:
#
# - go to bars more than once a month, had passengers that were not a kid, and were not widowed *OR*
# - go to bars more than once a month and are under the age of 30 *OR*
# - go to cheap restaurants more than 4 times a month and income is less than 50K.

# %%
# Check if Bar_gt1mo_noKids df have any widowed marital status; Since no widowed in this group, use this df
Bar_gt1mo_noKids['maritalStatus'].value_counts()
# Out:
# Single               199
# Married partner       93
# Unmarried partner     73
# Divorced              11
# Name: maritalStatus, dtype: int64

# %% [markdown]
# #### Acceptance rate for passengers who go to bars more than once a month, had passengers that were not a kid, and were not widowed is the same as above, 48%!

# %%
# The number of passengers who go to bars more than once a month and are under age 30
under30 = ['21', '26', 'below21']
groups = ['1~3', '4~8', 'gt8']

Bar_gt1mo_age30 = Bar_accepted.query('Bar in @groups and age in @under30')
Bar_gt1mo_age30
# Out:
#            destination  passanger weather  temperature  time coupon  \
# 90     No Urgent Place  Friend(s)   Sunny           80  10AM    Bar
# 101               Home      Alone   Sunny           55   6PM    Bar
# 112    No Urgent Place  Friend(s)   Sunny           80  10AM    Bar
# 123               Home      Alone   Sunny           55   6PM    Bar
# 127               Work      Alone   Sunny           55   7AM    Bar
# ...                ...        ...     ...          ...   ...    ...
# 12482  No Urgent Place  Friend(s)   Sunny           55  10PM    Bar
# 12485  No Urgent Place      Alone   Rainy           55  10AM    Bar
# 12488  No Urgent Place    Partner   Rainy           55   6PM    Bar
# 12525  No Urgent Place  Friend(s)   Sunny           80  10PM    Bar
# 12526  No Urgent Place  Friend(s)   Sunny           55  10PM    Bar
#
#       expiration  gender age      maritalStatus  ...  CoffeeHouse CarryAway  \
# 90            1d    Male  21             Single  ...        less1       1~3
# 101           1d    Male  21             Single  ...        less1       1~3
# 112           1d    Male  26  Unmarried partner  ...          gt8       4~8
# 123           1d    Male  26  Unmarried partner  ...          gt8       4~8
# 127           1d    Male  26  Unmarried partner  ...          gt8       4~8
# ...          ...     ...  ..                ...  ...          ...       ...
# 12482         2h  Female  26  Unmarried partner  ...        never       4~8
# 12485         1d  Female  26  Unmarried partner  ...        never       4~8
# 12488         2h  Female  26  Unmarried partner  ...        never       4~8
# 12525         1d    Male  21  Unmarried partner  ...        never       gt8
# 12526         2h    Male  21  Unmarried partner  ...        never       gt8
#
#       RestaurantLessThan20 Restaurant20To50 toCoupon_GEQ5min  \
# 90                   less1              1~3                1
# 101                  less1              1~3                1
# 112                    1~3            less1                1
# 123                    1~3            less1                1
# 127                    1~3            less1                1
# ...                    ...              ...              ...
# 12482                  4~8            less1                1
# 12485                  4~8            less1                1
# 12488                  4~8            less1                1
# 12525                  4~8              1~3                1
# 12526                  4~8              1~3                1
#
#       toCoupon_GEQ15min toCoupon_GEQ25min direction_same direction_opp  Y
# 90                    0                 0              0             1  1
# 101                   0                 0              1             0  1
# 112                   0                 0              0             1  1
# 123                   0                 0              1             0  1
# 127                   1                 1              0             1  1
# ...                 ...               ...            ...           ... ..
# 12482                 1                 0              0             1  1
# 12485                 1                 0              0             1  1
# 12488                 1                 0              0             1  1
# 12525                 1                 0              0             1  1
# 12526                 1                 0              0             1  1
#
# [236 rows x 25 columns]

# %%
# Percent of Drivers who go to bars gt once a month and under the age of 30 
pct_gt1mo_under30 = Bar_gt1mo_age30.shape[0] / Bar_accepted.shape[0]
pct_gt1mo_under30
# Out:
# 0.29949238578680204

# %% [markdown]
# #### Acceptance rate of drivers who go to bars more than once a month and under age 30 is approximately 30%

# %%
# Select data with customers getting coupons to cheap restaurant
cheap_Restnt = final_df.query('coupon =="Restaurant(<20)"')
cheap_Restnt
# Out:
#            destination  passanger weather  temperature  time           coupon  \
# 22     No Urgent Place      Alone   Sunny           55   2PM  Restaurant(<20)
# 29     No Urgent Place  Friend(s)   Sunny           80   2PM  Restaurant(<20)
# 31     No Urgent Place  Friend(s)   Sunny           80   6PM  Restaurant(<20)
# 42                Work      Alone   Sunny           55   7AM  Restaurant(<20)
# 44     No Urgent Place      Alone   Sunny           55   2PM  Restaurant(<20)
# ...                ...        ...     ...          ...   ...              ...
# 12666  No Urgent Place  Friend(s)   Snowy           30   2PM  Restaurant(<20)
# 12668  No Urgent Place      Alone   Sunny           80  10AM  Restaurant(<20)
# 12671  No Urgent Place    Partner   Snowy           30  10AM  Restaurant(<20)
# 12677             Home    Partner   Sunny           30   6PM  Restaurant(<20)
# 12678             Home    Partner   Sunny           30  10PM  Restaurant(<20)
#
#       expiration gender age maritalStatus  ...  CoffeeHouse CarryAway  \
# 22            1d   Male  21        Single  ...        less1       4~8
# 29            1d   Male  21        Single  ...        less1       4~8
# 31            2h   Male  21        Single  ...        less1       4~8
# 42            1d   Male  21        Single  ...        less1       4~8
# 44            1d   Male  46        Single  ...          4~8       1~3
# ...          ...    ...  ..           ...  ...          ...       ...
# 12666         1d   Male  26        Single  ...        never       1~3
# 12668         2h   Male  26        Single  ...        never       1~3
# 12671         1d   Male  26        Single  ...        never       1~3
# 12677         1d   Male  26        Single  ...        never       1~3
# 12678         2h   Male  26        Single  ...        never       1~3
#
#       RestaurantLessThan20 Restaurant20To50 toCoupon_GEQ5min  \
# 22                     4~8            less1                1
# 29                     4~8            less1                1
# 31                     4~8            less1                1
# 42                     4~8            less1                1
# 44                     1~3            never                1
# ...                    ...              ...              ...
# 12666                  4~8              1~3                1
# 12668                  4~8              1~3                1
# 12671                  4~8              1~3                1
# 12677                  4~8              1~3                1
# 12678                  4~8              1~3                1
#
#       toCoupon_GEQ15min toCoupon_GEQ25min direction_same direction_opp  Y
# 22                    0                 0              0             1  1
# 29                    1                 0              0             1  1
# 31                    1                 0              0             1  1
# 42                    0                 0              0             1  1
# 44                    0                 0              0             1  1
# ...                 ...               ...            ...           ... ..
# 12666                 0                 0              0             1  1
# 12668                 0                 0              0             1  1
# 12671                 0                 0              0             1  1
# 12677                 1                 1              0             1  1
# 12678                 1                 0              1             0  0
#
# [2653 rows x 25 columns]

# %%
# Accepted coupons for less expensive restaurants
cheapRestnt_accepted = final_df[(final_df['coupon'] == 'Restaurant(<20)') & (final_df['Y'] == 1)]
cheapRestnt_accepted
# Out:
#            destination  passanger weather  temperature  time           coupon  \
# 22     No Urgent Place      Alone   Sunny           55   2PM  Restaurant(<20)
# 29     No Urgent Place  Friend(s)   Sunny           80   2PM  Restaurant(<20)
# 31     No Urgent Place  Friend(s)   Sunny           80   6PM  Restaurant(<20)
# 42                Work      Alone   Sunny           55   7AM  Restaurant(<20)
# 44     No Urgent Place      Alone   Sunny           55   2PM  Restaurant(<20)
# ...                ...        ...     ...          ...   ...              ...
# 12662  No Urgent Place  Friend(s)   Sunny           80   6PM  Restaurant(<20)
# 12666  No Urgent Place  Friend(s)   Snowy           30   2PM  Restaurant(<20)
# 12668  No Urgent Place      Alone   Sunny           80  10AM  Restaurant(<20)
# 12671  No Urgent Place    Partner   Snowy           30  10AM  Restaurant(<20)
# 12677             Home    Partner   Sunny           30   6PM  Restaurant(<20)
#
#       expiration gender age maritalStatus  ...  CoffeeHouse CarryAway  \
# 22            1d   Male  21        Single  ...        less1       4~8
# 29            1d   Male  21        Single  ...        less1       4~8
# 31            2h   Male  21        Single  ...        less1       4~8
# 42            1d   Male  21        Single  ...        less1       4~8
# 44            1d   Male  46        Single  ...          4~8       1~3
# ...          ...    ...  ..           ...  ...          ...       ...
# 12662         2h   Male  26        Single  ...        never       1~3
# 12666         1d   Male  26        Single  ...        never       1~3
# 12668         2h   Male  26        Single  ...        never       1~3
# 12671         1d   Male  26        Single  ...        never       1~3
# 12677         1d   Male  26        Single  ...        never       1~3
#
#       RestaurantLessThan20 Restaurant20To50 toCoupon_GEQ5min  \
# 22                     4~8            less1                1
# 29                     4~8            less1                1
# 31                     4~8            less1                1
# 42                     4~8            less1                1
# 44                     1~3            never                1
# ...                    ...              ...              ...
# 12662                  4~8              1~3                1
# 12666                  4~8              1~3                1
# 12668                  4~8              1~3                1
# 12671                  4~8              1~3                1
# 12677                  4~8              1~3                1
#
#       toCoupon_GEQ15min toCoupon_GEQ25min direction_same direction_opp  Y
# 22                    0                 0              0             1  1
# 29                    1                 0              0             1  1
# 31                    1                 0              0             1  1
# 42                    0                 0              0             1  1
# 44                    0                 0              0             1  1
# ...                 ...               ...            ...           ... ..
# 12662                 0                 0              0             1  1
# 12666                 0                 0              0             1  1
# 12668                 0                 0              0             1  1
# 12671                 0                 0              0             1  1
# 12677                 1                 1              0             1  1
#
# [1881 rows x 25 columns]

# %%
cheapRestnt_accepted.shape[0]
# Out:
# 1881

# %%
# Acceptance rate of less expensive restaurant coupons
pct_cheapRestnt_accepted = cheapRestnt_accepted.shape[0] / cheap_Restnt.shape[0]
pct_cheapRestnt_accepted
# Out:
# 0.7090086694308331

# %%
# Examine age data and look at counts for each age reported
cheapRestnt_accepted['income'].value_counts()
# Out:
# $25000 - $37499     326
# $100000 or More     265
# $12500 - $24999     256
# $50000 - $62499     256
# $37500 - $49999     252
# Less than $12500    164
# $62500 - $74999     130
# $75000 - $87499     126
# $87500 - $99999     106
# Name: income, dtype: int64

# %%
# Examine data of RestaurantLessThan20 and look at each category
cheapRestnt_accepted['RestaurantLessThan20'].value_counts()
# Out:
# 1~3      780
# 4~8      556
# less1    299
# gt8      219
# never     27
# Name: RestaurantLessThan20, dtype: int64

# %%
# The number of passenger who go to cheap restaurants more than 4 times a month and income is less than 50K.
income_lt50 = ['$25000 - $37499', '$12500 - $24999', '$37500 - $49999', 'Less than $12500']
groups_gt4x = ['4~8', 'gt8']

cheapRestnt_gt4x_inclt50 = cheapRestnt_accepted.query('RestaurantLessThan20 in @groups_gt4x and income in @income_lt50')
cheapRestnt_gt4x_inclt50
# Out:
#            destination  passanger weather  temperature  time           coupon  \
# 154    No Urgent Place      Alone   Sunny           55   2PM  Restaurant(<20)
# 161    No Urgent Place  Friend(s)   Sunny           80   2PM  Restaurant(<20)
# 174               Work      Alone   Sunny           55   7AM  Restaurant(<20)
# 365    No Urgent Place      Alone   Sunny           55   2PM  Restaurant(<20)
# 370    No Urgent Place  Friend(s)   Sunny           80   6PM  Restaurant(<20)
# ...                ...        ...     ...          ...   ...              ...
# 12352  No Urgent Place  Friend(s)   Snowy           30   2PM  Restaurant(<20)
# 12355  No Urgent Place      Alone   Sunny           80  10AM  Restaurant(<20)
# 12356  No Urgent Place      Alone   Snowy           30  10AM  Restaurant(<20)
# 12367             Work      Alone   Snowy           30   7AM  Restaurant(<20)
# 12524  No Urgent Place  Friend(s)   Sunny           80   6PM  Restaurant(<20)
#
#       expiration  gender age      maritalStatus  ...  CoffeeHouse CarryAway  \
# 154           1d    Male  26             Single  ...          gt8       gt8
# 161           1d    Male  26             Single  ...          gt8       gt8
# 174           1d    Male  26             Single  ...          gt8       gt8
# 365           1d  Female  31    Married partner  ...        less1       4~8
# 370           2h  Female  31    Married partner  ...        less1       4~8
# ...          ...     ...  ..                ...  ...          ...       ...
# 12352         1d  Female  31             Single  ...          4~8     less1
# 12355         2h  Female  31             Single  ...          4~8     less1
# 12356         1d  Female  31             Single  ...          4~8     less1
# 12367         1d  Female  31             Single  ...          4~8     less1
# 12524         2h    Male  21  Unmarried partner  ...        never       gt8
#
#       RestaurantLessThan20 Restaurant20To50 toCoupon_GEQ5min  \
# 154                    gt8              gt8                1
# 161                    gt8              gt8                1
# 174                    gt8              gt8                1
# 365                    4~8            less1                1
# 370                    4~8            less1                1
# ...                    ...              ...              ...
# 12352                  4~8              1~3                1
# 12355                  4~8              1~3                1
# 12356                  4~8              1~3                1
# 12367                  4~8              1~3                1
# 12524                  4~8              1~3                1
#
#       toCoupon_GEQ15min toCoupon_GEQ25min direction_same direction_opp  Y
# 154                   0                 0              0             1  1
# 161                   1                 0              0             1  1
# 174                   0                 0              0             1  1
# 365                   0                 0              0             1  1
# 370                   1                 0              0             1  1
# ...                 ...               ...            ...           ... ..
# 12352                 0                 0              0             1  1
# 12355                 0                 0              0             1  1
# 12356                 1                 0              0             1  1
# 12367                 1                 0              0             1  1
# 12524                 0                 0              0             1  1
#
# [350 rows x 25 columns]

# %%
# Acceptance Rate of passengers who goes to cheap restaurant more than 4 times a month and income less than 50K
pct_cheapRestnt_gt4x_inclt50 = cheapRestnt_gt4x_inclt50.shape[0] / cheapRestnt_accepted.shape[0]
pct_cheapRestnt_gt4x_inclt50
# Out:
# 0.18607123870281764

# %% [markdown]
# #### Acceptance Rate of passengers who goes to cheap restaurant more than 4 times a month and income less than 50K is 19%

# %% [markdown]
# 9.  Based on these observations, what do you hypothesize about passengers who accepted the bar coupons?

# %% [markdown]
# ### Independent Investigation
#
# Using the bar coupon example as motivation, you are to explore one of the other coupon groups and try to determine the characteristics of passengers who accept the coupons.

# %%
# Summary Statistics 
final_df.groupby('coupon').size()
# Out:
# coupon
# Bar                      1913
# Carry out & Take away    2280
# Coffee House             3816
# Restaurant(20-50)        1417
# Restaurant(<20)          2653
# dtype: int64

# %%
CoffeeHse = final_df.query('coupon=="Coffee House"')
CoffeeHse
# Out:
#            destination  passanger weather  temperature  time        coupon  \
# 23     No Urgent Place  Friend(s)   Sunny           80  10AM  Coffee House
# 26     No Urgent Place  Friend(s)   Sunny           80   2PM  Coffee House
# 27     No Urgent Place  Friend(s)   Sunny           80   2PM  Coffee House
# 28     No Urgent Place  Friend(s)   Sunny           80   2PM  Coffee House
# 30     No Urgent Place  Friend(s)   Sunny           80   6PM  Coffee House
# ...                ...        ...     ...          ...   ...           ...
# 12656             Home      Alone   Snowy           30  10PM  Coffee House
# 12659             Work      Alone   Snowy           30   7AM  Coffee House
# 12674             Home      Alone   Rainy           55  10PM  Coffee House
# 12675             Home      Alone   Snowy           30  10PM  Coffee House
# 12681             Work      Alone   Snowy           30   7AM  Coffee House
#
#       expiration gender age    maritalStatus  ...  CoffeeHouse CarryAway  \
# 23            2h   Male  21           Single  ...        less1       4~8
# 26            1d   Male  21           Single  ...        less1       4~8
# 27            2h   Male  21           Single  ...        less1       4~8
# 28            1d   Male  21           Single  ...        less1       4~8
# 30            2h   Male  21           Single  ...        less1       4~8
# ...          ...    ...  ..              ...  ...          ...       ...
# 12656         2h   Male  31  Married partner  ...        never       4~8
# 12659         1d   Male  31  Married partner  ...        never       4~8
# 12674         2h   Male  26           Single  ...        never       1~3
# 12675         2h   Male  26           Single  ...        never       1~3
# 12681         1d   Male  26           Single  ...        never       1~3
#
#       RestaurantLessThan20 Restaurant20To50 toCoupon_GEQ5min  \
# 23                     4~8            less1                1
# 26                     4~8            less1                1
# 27                     4~8            less1                1
# 28                     4~8            less1                1
# 30                     4~8            less1                1
# ...                    ...              ...              ...
# 12656                  gt8            less1                1
# 12659                  gt8            less1                1
# 12674                  4~8              1~3                1
# 12675                  4~8              1~3                1
# 12681                  4~8              1~3                1
#
#       toCoupon_GEQ15min toCoupon_GEQ25min direction_same direction_opp  Y
# 23                    0                 0              0             1  0
# 26                    0                 0              0             1  0
# 27                    1                 0              0             1  0
# 28                    1                 0              0             1  0
# 30                    0                 0              0             1  0
# ...                 ...               ...            ...           ... ..
# 12656                 1                 0              0             1  0
# 12659                 0                 0              1             0  0
# 12674                 0                 0              1             0  0
# 12675                 1                 0              0             1  0
# 12681                 0                 0              1             0  0
#
# [3816 rows x 25 columns]

# %%
# Look at Coffee House since it is the most popular coupon used in the bar coupon e
CoffeeHse_accepted = final_df[(final_df['coupon'] == 'Coffee House') & (final_df['Y'] == 1)]
CoffeeHse_accepted
# Out:
#            destination  passanger weather  temperature  time        coupon  \
# 45     No Urgent Place  Friend(s)   Sunny           80  10AM  Coffee House
# 48     No Urgent Place  Friend(s)   Sunny           80   2PM  Coffee House
# 49     No Urgent Place  Friend(s)   Sunny           80   2PM  Coffee House
# 54     No Urgent Place  Friend(s)   Sunny           55   2PM  Coffee House
# 56     No Urgent Place      Alone   Sunny           55  10AM  Coffee House
# ...                ...        ...     ...          ...   ...           ...
# 12579             Home      Alone   Rainy           55  10PM  Coffee House
# 12601             Home      Alone   Rainy           55  10PM  Coffee House
# 12608             Work      Alone   Snowy           30   7AM  Coffee House
# 12624             Home      Alone   Rainy           55  10PM  Coffee House
# 12631             Work      Alone   Snowy           30   7AM  Coffee House
#
#       expiration  gender     age      maritalStatus  ...  CoffeeHouse  \
# 45            2h    Male      46             Single  ...          4~8
# 48            1d    Male      46             Single  ...          4~8
# 49            2h    Male      46             Single  ...          4~8
# 54            2h    Male      46             Single  ...          4~8
# 56            2h    Male      46             Single  ...          4~8
# ...          ...     ...     ...                ...  ...          ...
# 12579         2h    Male      21             Single  ...        never
# 12601         2h  Female  50plus           Divorced  ...        less1
# 12608         1d  Female  50plus           Divorced  ...        less1
# 12624         2h  Female      21  Unmarried partner  ...          4~8
# 12631         1d  Female      21  Unmarried partner  ...          4~8
#
#       CarryAway RestaurantLessThan20 Restaurant20To50 toCoupon_GEQ5min  \
# 45          1~3                  1~3            never                1
# 48          1~3                  1~3            never                1
# 49          1~3                  1~3            never                1
# 54          1~3                  1~3            never                1
# 56          1~3                  1~3            never                1
# ...         ...                  ...              ...              ...
# 12579       1~3                  1~3            less1                1
# 12601       1~3                  1~3            less1                1
# 12608       1~3                  1~3            less1                1
# 12624       1~3                  1~3            less1                1
# 12631       1~3                  1~3            less1                1
#
#       toCoupon_GEQ15min toCoupon_GEQ25min direction_same direction_opp  Y
# 45                    0                 0              0             1  1
# 48                    0                 0              0             1  1
# 49                    1                 0              0             1  1
# 54                    0                 0              0             1  1
# 56                    0                 0              0             1  1
# ...                 ...               ...            ...           ... ..
# 12579                 0                 0              1             0  1
# 12601                 0                 0              1             0  1
# 12608                 0                 0              1             0  1
# 12624                 0                 0              1             0  1
# 12631                 0                 0              1             0  1
#
# [1894 rows x 25 columns]

# %%
CoffeeHouse_accept = final_df[(final_df['coupon'] == 'Coffee House') & (final_df['Y'] == 1)]
CoffeeHouse_accept
# Out:
#            destination  passanger weather  temperature  time        coupon  \
# 45     No Urgent Place  Friend(s)   Sunny           80  10AM  Coffee House
# 48     No Urgent Place  Friend(s)   Sunny           80   2PM  Coffee House
# 49     No Urgent Place  Friend(s)   Sunny           80   2PM  Coffee House
# 54     No Urgent Place  Friend(s)   Sunny           55   2PM  Coffee House
# 56     No Urgent Place      Alone   Sunny           55  10AM  Coffee House
# ...                ...        ...     ...          ...   ...           ...
# 12579             Home      Alone   Rainy           55  10PM  Coffee House
# 12601             Home      Alone   Rainy           55  10PM  Coffee House
# 12608             Work      Alone   Snowy           30   7AM  Coffee House
# 12624             Home      Alone   Rainy           55  10PM  Coffee House
# 12631             Work      Alone   Snowy           30   7AM  Coffee House
#
#       expiration  gender     age      maritalStatus  ...  CoffeeHouse  \
# 45            2h    Male      46             Single  ...          4~8
# 48            1d    Male      46             Single  ...          4~8
# 49            2h    Male      46             Single  ...          4~8
# 54            2h    Male      46             Single  ...          4~8
# 56            2h    Male      46             Single  ...          4~8
# ...          ...     ...     ...                ...  ...          ...
# 12579         2h    Male      21             Single  ...        never
# 12601         2h  Female  50plus           Divorced  ...        less1
# 12608         1d  Female  50plus           Divorced  ...        less1
# 12624         2h  Female      21  Unmarried partner  ...          4~8
# 12631         1d  Female      21  Unmarried partner  ...          4~8
#
#       CarryAway RestaurantLessThan20 Restaurant20To50 toCoupon_GEQ5min  \
# 45          1~3                  1~3            never                1
# 48          1~3                  1~3            never                1
# 49          1~3                  1~3            never                1
# 54          1~3                  1~3            never                1
# 56          1~3                  1~3            never                1
# ...         ...                  ...              ...              ...
# 12579       1~3                  1~3            less1                1
# 12601       1~3                  1~3            less1                1
# 12608       1~3                  1~3            less1                1
# 12624       1~3                  1~3            less1                1
# 12631       1~3                  1~3            less1                1
#
#       toCoupon_GEQ15min toCoupon_GEQ25min direction_same direction_opp  Y
# 45                    0                 0              0             1  1
# 48                    0                 0              0             1  1
# 49                    1                 0              0             1  1
# 54                    0                 0              0             1  1
# 56                    0                 0              0             1  1
# ...                 ...               ...            ...           ... ..
# 12579                 0                 0              1             0  1
# 12601                 0                 0              1             0  1
# 12608                 0                 0              1             0  1
# 12624                 0                 0              1             0  1
# 12631                 0                 0              1             0  1
#
# [1894 rows x 25 columns]

# %%
# Percent acceptance of Coffee House coupons
pct_CH_acceptance = CoffeeHouse_accept.shape[0] / CoffeeHouse.shape[0]
pct_CH_acceptance
# Out:
# 0.49633123689727465

# %% [markdown]
# #### Acceptance rate of CoffeeHouse coupons is 50%

# %%
# Examine the number of times the customer visited Coffee House
CoffeeHouse_accept['CoffeeHouse'].value_counts()
# Out:
# 1~3      660
# less1    506
# 4~8      346
# gt8      225
# never    157
# Name: CoffeeHouse, dtype: int64

# %%
# The number of passengers who go to Coffee House less than or equal to 3 times per month 
groups_CHlt3x = ['1~3', 'less1', 'never']

CH_lt3x_total = CoffeeHouse_accept.query('CoffeeHouse in @groups_CHlt3x')
CH_lt3x_total
# Out:
#            destination  passanger weather  temperature  time        coupon  \
# 67     No Urgent Place  Friend(s)   Sunny           80  10AM  Coffee House
# 69     No Urgent Place  Friend(s)   Sunny           80   2PM  Coffee House
# 70     No Urgent Place  Friend(s)   Sunny           80   2PM  Coffee House
# 81                Home      Alone   Sunny           80   6PM  Coffee House
# 89     No Urgent Place  Friend(s)   Sunny           80  10AM  Coffee House
# ...                ...        ...     ...          ...   ...           ...
# 12476             Work      Alone   Snowy           30   7AM  Coffee House
# 12565             Work      Alone   Snowy           30   7AM  Coffee House
# 12579             Home      Alone   Rainy           55  10PM  Coffee House
# 12601             Home      Alone   Rainy           55  10PM  Coffee House
# 12608             Work      Alone   Snowy           30   7AM  Coffee House
#
#       expiration  gender     age    maritalStatus  ...  CoffeeHouse CarryAway  \
# 67            2h    Male      46  Married partner  ...          1~3       1~3
# 69            2h    Male      46  Married partner  ...          1~3       1~3
# 70            1d    Male      46  Married partner  ...          1~3       1~3
# 81            2h    Male      46  Married partner  ...          1~3       1~3
# 89            2h    Male      21           Single  ...        less1       1~3
# ...          ...     ...     ...              ...  ...          ...       ...
# 12476         1d    Male      41         Divorced  ...        less1     less1
# 12565         1d  Female      26  Married partner  ...        less1       1~3
# 12579         2h    Male      21           Single  ...        never       1~3
# 12601         2h  Female  50plus         Divorced  ...        less1       1~3
# 12608         1d  Female  50plus         Divorced  ...        less1       1~3
#
#       RestaurantLessThan20 Restaurant20To50 toCoupon_GEQ5min  \
# 67                     1~3            less1                1
# 69                     1~3            less1                1
# 70                     1~3            less1                1
# 81                     1~3            less1                1
# 89                   less1              1~3                1
# ...                    ...              ...              ...
# 12476                  1~3              4~8                1
# 12565                  1~3            never                1
# 12579                  1~3            less1                1
# 12601                  1~3            less1                1
# 12608                  1~3            less1                1
#
#       toCoupon_GEQ15min toCoupon_GEQ25min direction_same direction_opp  Y
# 67                    0                 0              0             1  1
# 69                    1                 0              0             1  1
# 70                    1                 0              0             1  1
# 81                    0                 0              0             1  1
# 89                    0                 0              0             1  1
# ...                 ...               ...            ...           ... ..
# 12476                 0                 0              1             0  1
# 12565                 0                 0              1             0  1
# 12579                 0                 0              1             0  1
# 12601                 0                 0              1             0  1
# 12608                 0                 0              1             0  1
#
# [1323 rows x 25 columns]

# %%
pct_CH_lt3x = CH_lt3x_total.shape[0] / CoffeeHouse_accept.shape[0]
pct_CH_lt3x
# Out:
# 0.6985216473072862

# %% [markdown]
# #### Acceptance rate of cutomers who  will go to Coffee House less than or equal to 3 times per month is 70%

# %%
# Examine categories of marital status
CoffeeHouse_accept['maritalStatus'].value_counts()
# Out:
# Single               770
# Married partner      720
# Unmarried partner    318
# Divorced              74
# Widowed               12
# Name: maritalStatus, dtype: int64

# %%
not_married = ['Single', 'Unmarried partner', 'Divorced', 'Widowed']
CH_lt3x_notmarr = CH_lt3x_total.query('maritalStatus in @not_married')
CH_lt3x_notmarr
# Out:
#            destination  passanger weather  temperature  time        coupon  \
# 89     No Urgent Place  Friend(s)   Sunny           80  10AM  Coffee House
# 92     No Urgent Place  Friend(s)   Sunny           80   2PM  Coffee House
# 93     No Urgent Place  Friend(s)   Sunny           80   2PM  Coffee House
# 94     No Urgent Place  Friend(s)   Sunny           80   2PM  Coffee House
# 96     No Urgent Place  Friend(s)   Sunny           80   6PM  Coffee House
# ...                ...        ...     ...          ...   ...           ...
# 12469             Home      Alone   Rainy           55  10PM  Coffee House
# 12476             Work      Alone   Snowy           30   7AM  Coffee House
# 12579             Home      Alone   Rainy           55  10PM  Coffee House
# 12601             Home      Alone   Rainy           55  10PM  Coffee House
# 12608             Work      Alone   Snowy           30   7AM  Coffee House
#
#       expiration  gender     age maritalStatus  ...  CoffeeHouse CarryAway  \
# 89            2h    Male      21        Single  ...        less1       1~3
# 92            1d    Male      21        Single  ...        less1       1~3
# 93            2h    Male      21        Single  ...        less1       1~3
# 94            1d    Male      21        Single  ...        less1       1~3
# 96            2h    Male      21        Single  ...        less1       1~3
# ...          ...     ...     ...           ...  ...          ...       ...
# 12469         2h    Male      41      Divorced  ...        less1     less1
# 12476         1d    Male      41      Divorced  ...        less1     less1
# 12579         2h    Male      21        Single  ...        never       1~3
# 12601         2h  Female  50plus      Divorced  ...        less1       1~3
# 12608         1d  Female  50plus      Divorced  ...        less1       1~3
#
#       RestaurantLessThan20 Restaurant20To50 toCoupon_GEQ5min  \
# 89                   less1              1~3                1
# 92                   less1              1~3                1
# 93                   less1              1~3                1
# 94                   less1              1~3                1
# 96                   less1              1~3                1
# ...                    ...              ...              ...
# 12469                  1~3              4~8                1
# 12476                  1~3              4~8                1
# 12579                  1~3            less1                1
# 12601                  1~3            less1                1
# 12608                  1~3            less1                1
#
#       toCoupon_GEQ15min toCoupon_GEQ25min direction_same direction_opp  Y
# 89                    0                 0              0             1  1
# 92                    0                 0              0             1  1
# 93                    1                 0              0             1  1
# 94                    1                 0              0             1  1
# 96                    0                 0              0             1  1
# ...                 ...               ...            ...           ... ..
# 12469                 0                 0              1             0  1
# 12476                 0                 0              1             0  1
# 12579                 0                 0              1             0  1
# 12601                 0                 0              1             0  1
# 12608                 0                 0              1             0  1
#
# [808 rows x 25 columns]

# %%
CH_lt3x_notmarr.shape[0] / CoffeeHouse_accept.shape[0]
# Out:
# 0.426610348468849
